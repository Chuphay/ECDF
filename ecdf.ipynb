# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from statsmodels.distributions.empirical_distribution import ECDF
ecdf = ECDF([3, 3, 1, 4])
ecdf([3, 55, 0.5, 1.5])
# Out:
# array([ 0.75,  1.  ,  0.  ,  0.25])

# %%
x = sorted([72, 35, 28, 97, 96])
ecdf = ECDF(x)
plt.step(ecdf.x, ecdf.y)

# %%
from pandas import DataFrame
import pandas as pd

# %%
df_1 = pd.read_csv("tests/file1.csv",  names = ['student_id', 'course','university','date', 'score'])
df_1
# Out:
#    student_id   course               university        date  score
# 0     9812345  Algebra  Port Chester University  2015-03-17   75.5
# 1           1     Math           ABC University  2015-04-16   90.0
# 2           2     Math           DEF University  2015-04-16   10.0
# 3           3     Math           DEF University  2015-04-16   35.0
# 4           1  English           DEF University  2015-04-16   45.0
# 5           2  English           ABC University  2015-04-16   10.0
# 6           3  English           ABC University  2015-04-16   35.0

# %%
df_2 = pd.read_csv("tests/file2.csv",  names = ['student_id', 'course','university','date', 'score'])
df_2
# Out:
#    student_id     course      university        date  score
# 0           1    Science  ABC University  2015-04-16     77
# 1           2    Science  DEF University  2015-04-16     35
# 2           3    Science  DEF University  2015-04-16     60
# 3           1    History  DEF University  2015-04-16     22
# 4           2    History  ABC University  2015-04-16    100
# 5           3    History  ABC University  2015-04-16     90
# 6           1  Geography  GHI University  2015-04-16     90
# 7           2  Geography  GHI University  2015-04-16     30

# %%
df = df_1.append(df_2)
df
# Out:
#    student_id     course               university        date  score
# 0     9812345    Algebra  Port Chester University  2015-03-17   75.5
# 1           1       Math           ABC University  2015-04-16   90.0
# 2           2       Math           DEF University  2015-04-16   10.0
# 3           3       Math           DEF University  2015-04-16   35.0
# 4           1    English           DEF University  2015-04-16   45.0
# 5           2    English           ABC University  2015-04-16   10.0
# 6           3    English           ABC University  2015-04-16   35.0
# 0           1    Science           ABC University  2015-04-16   77.0
# 1           2    Science           DEF University  2015-04-16   35.0
# 2           3    Science           DEF University  2015-04-16   60.0
# 3           1    History           DEF University  2015-04-16   22.0
# 4           2    History           ABC University  2015-04-16  100.0
# 5           3    History           ABC University  2015-04-16   90.0
# ...

# %%
abc = df[df['university'] == "DEF University"]
m = abc.groupby("student_id").mean()
m
# Out:
#             score
# student_id
# 1            33.5
# 2            22.5
# 3            47.5

# %%
ecdf = ECDF(m['score'].values)
plt.step(ecdf.x, ecdf.y);
